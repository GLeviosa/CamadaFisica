# %%
import suaBibSignal as sbs
import numpy as np
import sounddevice as sd
import matplotlib.pyplot as plt
import soundfile   as sf

# %%
mySignal = sbs.signalMeu()
A = 1.5
T = 4
fs = mySignal.freqAmostragem

# %%
x, s = mySignal.generateSin(5, A, T, fs)
mySignal.plotFFT(x,fs)

# %%
plt.figure()
plt.plot(x, s)
